# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# before starting the url make sure that the url is not dynamically loaded and there are different pages in the url-webiste page, only then this code will work,
# or else we might have to use selenium and webdriver to extract the data 

# actual url=https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs
# upon examining the webpage, we can see there are multiple pages in the url and each one's url is same except the ending so we have divided the webpage"url into two parts so that it can iterate through each page 
# Initialize the starting URL
base_url = 'https://www.magicbricks.com'
initial_url = '/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-1'#change this line accordingly 
current_url = base_url + initial_url

# %%
# List to store property data
property_data = []

# Function to extract label and value
def extract_label_and_value(card_soup, data_summary):
    item = card_soup.find("div", {"data-summary": data_summary})
    if item:
        label = item.find("div", class_="mb-srp__card__summary--label").get_text().strip()
        value = item.find("div", class_="mb-srp__card__summary--value").get_text().strip()
        return label, value
    return None, None

# Function to extract property name
def extract_property_name(card):
    society_div_element = card.find('div', class_='mb-srp__card__society')
    property_name = society_div_element.find('a', class_='mb-srp__card__society--name').text.strip() if society_div_element else None
    return property_name

# Function to extract property details from a property card
def extract_property_details(card):
    title = card.find('h2', class_='mb-srp__card--title').text.strip()
    price = card.find('div', class_='mb-srp__card__price--amount').text.strip()
    property_name = extract_property_name(card)  # Extract property name
    
    figure_count_element = card.find('span', class_='mb-srp__card__photo__fig--count')
    figure_count = figure_count_element.get_text(strip=True) if figure_count_element else "N/A"
    
    price_per_sqft_div_element = card.find('div', class_='mb-srp__card__price--size')
    price_per_sqft_div = price_per_sqft_div_element.get_text(strip=True) if price_per_sqft_div_element else "N/A"
    
    # List of possible data-summary values for carpet area
    carpet_area_summaries = ["carpet-area", "super-area", "plot-area"]

    # Extract details
    carpet_area_label, carpet_area_value = extract_label_and_value(card, carpet_area_summaries)
    status_label, status_value = extract_label_and_value(card, "status")
    floor_label, floor_value = extract_label_and_value(card, "floor")
    transaction_label, transaction_value = extract_label_and_value(card, "transaction")
    furnishing_label, furnishing_value = extract_label_and_value(card, "furnishing")
    overlooking_label, overlooking_value = extract_label_and_value(card, "overlooking")
    ownership_label, ownership_value = extract_label_and_value(card, "ownership")
    parking_label, parking_value = extract_label_and_value(card, "parking")
    bathroom_label, bathroom_value = extract_label_and_value(card, "bathroom")
    balcony_label, balcony_value = extract_label_and_value(card, "balcony")

    return {
        'Title': title,
        'Price': price,
        'Property Name': property_name,
        'Figure Count': figure_count,
        'Price per Sqft': price_per_sqft_div,
        'Carpet Area Label': carpet_area_label,
        'Carpet Area Value': carpet_area_value,
        'Status Label': status_label,
        'Status Value': status_value,
        'Floor Label': floor_label,
        'Floor Value': floor_value,
        'Transaction Label': transaction_label,
        'Transaction Value': transaction_value,
        'Furnishing Label': furnishing_label,
        'Furnishing Value': furnishing_value,
        'Overlooking Label': overlooking_label,
        'Overlooking Value': overlooking_value,
        'Ownership Label': ownership_label,
        'Ownership Value': ownership_value,
        'Parking Label': parking_label,
        'Parking Value': parking_value,
        'Bathroom Label': bathroom_label,
        'Bathroom Value': bathroom_value,
        'Balcony Label': balcony_label,
        'Balcony Value': balcony_value
    }

# Function to scrape a page and append data to property_data
def scrape_page(url):
    print(f"Scraping URL: {url}")  # Debug statement
    r = requests.get(url)
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "lxml")
    
    # Find all property cards
    property_cards = soup.find_all('div', class_='mb-srp__card')

    for card in property_cards:
        property_data.append(extract_property_details(card))

    # Find the "Next" page link
    np_li = soup.find("li", class_='mb-pagination--next')
    if np_li:
        np = np_li.find('a').get('href')
        if np:
            next_url = base_url + np
            scrape_page(next_url)  # Recursively scrape the next page
        else:
            print("Next page URL is None. Stopping recursion.")
    else:
        print("No more pages to scrape.")

# Start scraping from the start URL
scrape_page(current_url)

# Create a DataFrame from property_data
df = pd.DataFrame(property_data)

# Print the DataFrame
print(df)
# Out:
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-1
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-2
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-3
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-4
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-5
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-6
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-7
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-8
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-9
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-10
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-11
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-12
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-13
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-14
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-15
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-16
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-17
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-18
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-19
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-20
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-21
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-22
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-23
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-24
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-25
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-26
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-27
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-28
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-29
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-30
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-31
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-32
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-33
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-34
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-35
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-36
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-37
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-38
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-39
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-40
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-41
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-42
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-43
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-44
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-45
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-46
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-47
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-48
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-49
# Scraping URL: https://www.magicbricks.com/property-for-sale-in-bannerghatta-main-road-bangalore-pppfs/page-50
# Next page URL is None. Stopping recursion.
#                                                   Title           Price  \
# 0     Plot/Land for Sale in Nobo Nagar, Bannerghatta...        ₹1.20 Cr
# 1     3 BHK Apartment for Sale in Phase 2 Tejaswini ...        ₹1.25 Cr
# 2     2 BHK Builder Floor for Sale in Bannerghatta R...         ₹45 Lac
# 3     3 BHK Apartment for Sale in BTM Layout, Banner...        ₹1.34 Cr
# 4     4 BHK Villa for Sale in Bannerghatta Road Bang...        ₹1.85 Cr
# ...                                                 ...             ...
# 1495  4 BHK Apartment for Sale in Panduranga Nagar, ...        ₹6.20 Cr
# 1496  3 BHK Builder Floor for Sale in Seshadripuram,...        ₹1.85 Cr
# 1497  Plot/Land for Sale in Bannerghatta, Bannerghat...         ₹68 Lac
# 1498  3 BHK Penthouse for Sale in Phase 4 JP Nagar, ...        ₹3.10 Cr
# 1499  Plot/Land for Sale in Bannerghatta Road Bangalore  Call for Price
#
#                Property Name Figure Count   Price per Sqft Carpet Area Label  \
# 0                       None           3+  ₹10000 per sqft         Plot Area
# 1            Pariwar Passion           8+              N/A       Carpet Area
# 2                       None          12+   ₹4186 per sqft        Super Area
# 3          SNN Raj Bay Vista           2+   ₹8961 per sqft       Carpet Area
# 4              Dwara Orville           3+              N/A       Carpet Area
# ...                      ...          ...              ...               ...
# 1495  Artisane Forest Breeze          12+  ₹15796 per sqft       Carpet Area
# 1496                    None          N/A  ₹11555 per sqft        Super Area
# 1497   Upkar Kamakshi Layout           2+   ₹6182 per sqft         Plot Area
# 1498      Vaishnavi Terraces           9+  ₹11923 per sqft       Carpet Area
# 1499          Jayaram Layout          N/A              N/A         Plot Area
#
#      Carpet Area Value        Status Label      Status Value  \
# 0            1200 sqft                None              None
# 1            1610 sqft              Status     Ready to Move
# 2            1075 sqft              Status     Ready to Move
# 3            1085 sqft  Under Construction  Poss. by Jan '26
# 4            2800 sqft                None              None
# ...                ...                 ...               ...
# 1495         2747 sqft              Status     Ready to Move
# 1496         1601 sqft              Status     Ready to Move
# 1497         1100 sqft                None              None
# 1498         2450 sqft              Status     Ready to Move
# 1499         2000 sqft                None              None
#
#                           Floor Label  ... Overlooking Label  \
# 0     floors allowed for construction  ...       overlooking
# 1                               Floor  ...              None
# 2                               Floor  ...              None
# 3                               Floor  ...       overlooking
# 4                                None  ...              None
# ...                               ...  ...               ...
# 1495                            Floor  ...       overlooking
# 1496                            Floor  ...       overlooking
# 1497  floors allowed for construction  ...       overlooking
# 1498                            Floor  ...       overlooking
# 1499                             None  ...              None
#
#                  Overlooking Value Ownership Label Ownership Value  \
# 0                        Main Road       Ownership        Freehold
# 1                             None            None            None
# 2                             None            None            None
# 3     Garden/Park, Pool, Main Road       Ownership        Freehold
# 4                             None            None            None
# ...                            ...             ...             ...
# 1495        Garden/Park, Main Road       Ownership        Freehold
# 1496                     Main Road       Ownership        Freehold
# 1497                   Garden/Park       Ownership        Freehold
# 1498                   Garden/Park       Ownership        Freehold
# 1499                          None            None            None
#
#      Parking Label Parking Value Bathroom Label Bathroom Value Balcony Label  \
# 0             None          None           None           None          None
# 1             None          None       Bathroom              3       Balcony
# 2             None          None       Bathroom              2          None
# 3      Car Parking    1 Covered,       Bathroom              2       Balcony
# 4      Car Parking     2 Covered       Bathroom              4       Balcony
# ...            ...           ...            ...            ...           ...
# 1495   Car Parking     2 Covered       Bathroom              4       Balcony
# 1496   Car Parking     1 Covered       Bathroom              3       Balcony
# 1497          None          None           None           None          None
# 1498   Car Parking     1 Covered       Bathroom              4       Balcony
# 1499          None          None           None           None          None
#
#      Balcony Value
# 0             None
# 1                2
# 2             None
# 3                1
# 4                3
# ...            ...
# 1495             3
# 1496             1
# 1497          None
# 1498             3
# 1499          None
#
# [1500 rows x 25 columns]

# %%
# Define the filename for the output file
csv_filename = 'C:/Users/drjun/OneDrive/Desktop/blore csv/banneghatta_rd_blore.csv'

# Save the DataFrame to CSV and Excel files
df.to_csv(csv_filename, index=False)

print("Data has been saved to CSV file:", csv_filename)
# Out:
# Data has been saved to CSV file: C:/Users/drjun/OneDrive/Desktop/blore csv/banneghatta_rd_blore.csv
